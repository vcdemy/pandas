# %% [markdown]
# <a href="https://colab.research.google.com/github/vcdemy/pandas/blob/main/pandas_%E9%87%8D%E8%A4%87%E5%80%BC%E8%99%95%E7%90%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 重複值處理

# %% [markdown]
# * .unique(): 回傳不重複的資料。
# * .duplicated(): 回傳是否重複的bool結果。
# * .drop_duplicates(): 刪除重複資料。

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(987)
categories = np.random.choice(['A','B','C'], 10)
values = np.random.randint(1, 6, 10)

# %%
df = pd.DataFrame({'categories':categories, 'values':values})

# %%
df
# Out:
#   categories  values
# 0          B       5
# 1          C       4
# 2          C       2
# 3          C       4
# 4          B       3
# 5          C       1
# 6          C       3
# 7          A       2
# 8          C       2
# 9          C       3

# %% [markdown]
# ## .unique()

# %% [markdown]
# 如果只是要找Series裡面不重複的資料，則使用.unique()。
#
# https://pandas.pydata.org/docs/reference/api/pandas.unique.html

# %%
df['categories'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
df['values'].unique()
# Out:
# array([5, 4, 2, 3, 1])

# %% [markdown]
# ## .duplicated()

# %% [markdown]
# 參數：
#
# subset: 設定要比對的欄位。
#
# keep: {'first', 'last', False} 看看是要保留第一筆資料，最後一筆資料，或者只要重複就標成True。預設是'first'。
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html

# %%
df
# Out:
#   categories  values
# 0          B       5
# 1          C       4
# 2          C       2
# 3          C       4
# 4          B       3
# 5          C       1
# 6          C       3
# 7          A       2
# 8          C       2
# 9          C       3

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
df.duplicated(keep='last')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated(keep=False)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
df.duplicated(subset=['categories'])
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# dtype: bool

# %% [markdown]
# ## .drop_duplicates()

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %%
df
# Out:
#   categories  values
# 0          B       5
# 1          C       4
# 2          C       2
# 3          C       4
# 4          B       3
# 5          C       1
# 6          C       3
# 7          A       2
# 8          C       2
# 9          C       3

# %%
df.drop_duplicates()
# Out:
#   categories  values
# 0          B       5
# 1          C       4
# 2          C       2
# 4          B       3
# 5          C       1
# 6          C       3
# 7          A       2

# %%
df.drop_duplicates(keep='last')
# Out:
#   categories  values
# 0          B       5
# 3          C       4
# 4          B       3
# 5          C       1
# 7          A       2
# 8          C       2
# 9          C       3

# %%
df.drop_duplicates(subset=['categories'])
# Out:
#   categories  values
# 0          B       5
# 1          C       4
# 7          A       2
