# %% [markdown]
# <a href="https://colab.research.google.com/github/vcdemy/pandas/blob/main/pandas_rename.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # .rename() => 變更欄(Columns)或索引(Index)名稱

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(987)
data = np.random.random((3, 3))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           0         1         2
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df.columns = ['col', 'col2', 'col3']

# %%
df
# Out:
#         col      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %% [markdown]
# ## 更改欄位名稱

# %%
df.rename(columns={'col':'col1'})
# Out:
#        col1      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df
# Out:
#         col      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df = df.rename(columns={'col':'col1'})

# %%
df
# Out:
#        col1      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df.rename(columns={'col1':'C1', 'col3':'C3'})
# Out:
#          C1      col2        C3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df
# Out:
#        col1      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df.rename({'col1':'C1', 'col3':'C3'}, axis='columns')
# Out:
#          C1      col2        C3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %% [markdown]
# ## 更改索引名稱

# %%
df
# Out:
#        col1      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df.rename(index={0:'R1', 2:'R3'})
# Out:
#         col1      col2      col3
# R1  0.405969  0.392239  0.878866
# 1   0.459129  0.848916  0.919238
# R3  0.912206  0.962871  0.030044

# %%
df
# Out:
#        col1      col2      col3
# 0  0.405969  0.392239  0.878866
# 1  0.459129  0.848916  0.919238
# 2  0.912206  0.962871  0.030044

# %%
df.rename({0:'R1', 2:'R3'}, axis="index")
# Out:
#         col1      col2      col3
# R1  0.405969  0.392239  0.878866
# 1   0.459129  0.848916  0.919238
# R3  0.912206  0.962871  0.030044

# %%
df.index = ['row1', 'row2', 'row3']

# %%
df
# Out:
#           col1      col2      col3
# row1  0.405969  0.392239  0.878866
# row2  0.459129  0.848916  0.919238
# row3  0.912206  0.962871  0.030044
